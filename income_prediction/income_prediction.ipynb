# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from pprint import *

# %%
import seaborn
seaborn.set()

# %%
train = pd.read_csv('train.csv')

# %%
test = pd.read_csv('test.csv')

# %%
train
# Out:
#           ID  Age         Workclass     Education         Marital.Status  \
# 0          1   39         State-gov     Bachelors          Never-married
# 1          2   50  Self-emp-not-inc     Bachelors     Married-civ-spouse
# 2          3   38           Private       HS-grad               Divorced
# 3          4   53           Private          11th     Married-civ-spouse
# 4          5   28           Private     Bachelors     Married-civ-spouse
# 5          6   37           Private       Masters     Married-civ-spouse
# 6          7   49           Private           9th  Married-spouse-absent
# 7          8   52  Self-emp-not-inc       HS-grad     Married-civ-spouse
# 8          9   31           Private       Masters          Never-married
# 9         10   42           Private     Bachelors     Married-civ-spouse
# 10        11   37           Private  Some-college     Married-civ-spouse
# 11        12   30         State-gov     Bachelors     Married-civ-spouse
# 12        13   23           Private     Bachelors          Never-married
# 13        14   32           Private    Assoc-acdm          Never-married
# 14        15   40           Private     Assoc-voc     Married-civ-spouse
# 15        16   34           Private       7th-8th     Married-civ-spouse
# 16        17   25  Self-emp-not-inc       HS-grad          Never-married
# 17        18   32           Private       HS-grad          Never-married
# 18        19   38           Private          11th     Married-civ-spouse
# 19        20   43  Self-emp-not-inc       Masters               Divorced
# 20        21   40           Private     Doctorate     Married-civ-spouse
# 21        22   54           Private       HS-grad              Separated
# 22        23   35       Federal-gov           9th     Married-civ-spouse
# 23        24   43           Private          11th     Married-civ-spouse
# 24        25   59           Private       HS-grad               Divorced
# 25        26   56         Local-gov     Bachelors     Married-civ-spouse
# 26        27   19           Private       HS-grad          Never-married
# 27        28   54               NaN  Some-college     Married-civ-spouse
# 28        29   39           Private       HS-grad               Divorced
# 29        30   49           Private       HS-grad     Married-civ-spouse
# ...      ...  ...               ...           ...                    ...
# 25799  25800   46       Federal-gov       Masters     Married-civ-spouse
# 25800  25801   54      Self-emp-inc  Some-college     Married-civ-spouse
# 25801  25802   34           Private       HS-grad     Married-civ-spouse
# 25802  25803   67               NaN     Doctorate     Married-civ-spouse
# 25803  25804   62           Private     Bachelors     Married-civ-spouse
# 25804  25805   30           Private  Some-college     Married-civ-spouse
# 25805  25806   19           Private       HS-grad          Never-married
# 25806  25807   49               NaN       7th-8th     Married-civ-spouse
# 25807  25808   27           Private     Assoc-voc          Never-married
# 25808  25809   36           Private  Some-college     Married-civ-spouse
# 25809  25810   52           Private     Bachelors     Married-civ-spouse
# 25810  25811   47           Private          12th  Married-spouse-absent
# 25811  25812   57         Local-gov       HS-grad               Divorced
# 25812  25813   64           Private  Some-college  Married-spouse-absent
# 25813  25814   56               NaN       HS-grad               Divorced
# 25814  25815   53           Private          11th                Widowed
# 25815  25816   53           Private     Bachelors     Married-civ-spouse
# 25816  25817   31           Private  Some-college              Separated
# 25817  25818   41           Private     Bachelors     Married-civ-spouse
# 25818  25819   45         Local-gov       HS-grad              Separated
# 25819  25820   63               NaN     Bachelors     Married-civ-spouse
# 25820  25821   45         State-gov       HS-grad               Divorced
# 25821  25822   23           Private  Some-college          Never-married
# 25822  25823   39         Local-gov       Masters     Married-civ-spouse
# 25823  25824   31           Private     Assoc-voc     Married-civ-spouse
# 25824  25825   35  Self-emp-not-inc     Bachelors     Married-civ-spouse
# 25825  25826   54           Private       Masters     Married-civ-spouse
# 25826  25827   22               NaN  Some-college          Never-married
# 25827  25828   40         Local-gov     Bachelors               Divorced
# 25828  25829   55  Self-emp-not-inc     Bachelors         Married-civ-sp
#
#               Occupation    Relationship                Race     Sex  \
# 0           Adm-clerical   Not-in-family               White    Male
# 1        Exec-managerial         Husband               White    Male
# 2      Handlers-cleaners   Not-in-family               White    Male
# 3      Handlers-cleaners         Husband               Black    Male
# 4         Prof-specialty            Wife               Black  Female
# 5        Exec-managerial            Wife               White  Female
# 6          Other-service   Not-in-family               Black  Female
# 7        Exec-managerial         Husband               White    Male
# 8         Prof-specialty   Not-in-family               White  Female
# 9        Exec-managerial         Husband               White    Male
# 10       Exec-managerial         Husband               Black    Male
# 11        Prof-specialty         Husband  Asian-Pac-Islander    Male
# 12          Adm-clerical       Own-child               White  Female
# 13                 Sales   Not-in-family               Black    Male
# 14          Craft-repair         Husband  Asian-Pac-Islander    Male
# 15      Transport-moving         Husband  Amer-Indian-Eskimo    Male
# 16       Farming-fishing       Own-child               White    Male
# 17     Machine-op-inspct       Unmarried               White    Male
# 18                 Sales         Husband               White    Male
# 19       Exec-managerial       Unmarried               White  Female
# 20        Prof-specialty         Husband               White    Male
# 21         Other-service       Unmarried               Black  Female
# 22       Farming-fishing         Husband               Black    Male
# 23      Transport-moving         Husband               White    Male
# 24          Tech-support       Unmarried               White  Female
# 25          Tech-support         Husband               White    Male
# 26          Craft-repair       Own-child               White    Male
# 27                   NaN         Husband  Asian-Pac-Islander    Male
# 28       Exec-managerial   Not-in-family               White    Male
# 29          Craft-repair         Husband               White    Male
# ...                  ...             ...                 ...     ...
# 25799       Armed-Forces         Husband               White    Male
# 25800              Sales         Husband               White    Male
# 25801       Craft-repair         Husband               White    Male
# 25802                NaN         Husband               White    Male
# 25803              Sales         Husband               White    Male
# 25804  Handlers-cleaners         Husband               White    Male
# 25805      Other-service       Own-child               White    Male
# 25806                NaN         Husband               White    Male
# 25807  Machine-op-inspct       Unmarried               White    Male
# 25808       Craft-repair         Husband               White    Male
# 25809  Machine-op-inspct         Husband               White    Male
# 25810    Exec-managerial   Not-in-family               White  Female
# 25811    Protective-serv   Not-in-family               White  Female
# 25812    Exec-managerial       Unmarried               White  Female
# 25813                NaN   Not-in-family               White    Male
# 25814      Other-service       Own-child               White  Female
# 25815       Craft-repair         Husband               White    Male
# 25816              Sales       Unmarried  Asian-Pac-Islander    Male
# 25817    Exec-managerial         Husband               White    Male
# 25818      Other-service       Unmarried               Black  Female
# 25819                NaN         Husband               White    Male
# 25820       Adm-clerical  Other-relative               White  Female
# 25821      Other-service   Not-in-family               White  Female
# 25822     Prof-specialty         Husband               White    Male
# 25823    Exec-managerial         Husband               White    Male
# 25824    Farming-fishing         Husband               White    Male
# 25825   Transport-moving         Husband               White    Male
# 25826                NaN       Own-child               White  Female
# 25827     Prof-specialty       Unmarried               White  Female
# 25828                NaN             NaN                 NaN     NaN
#
#        Hours.Per.Week Native.Country Income.Group
# 0                40.0  United-States        <=50K
# 1                13.0  United-States        <=50K
# 2                40.0  United-States        <=50K
# 3                40.0  United-States        <=50K
# 4                40.0           Cuba        <=50K
# 5                40.0  United-States        <=50K
# 6                16.0        Jamaica        <=50K
# 7                45.0  United-States         >50K
# 8                50.0  United-States         >50K
# 9                40.0  United-States         >50K
# 10               80.0  United-States         >50K
# 11               40.0          India         >50K
# 12               30.0  United-States        <=50K
# 13               50.0  United-States        <=50K
# 14               40.0            NaN         >50K
# 15               45.0         Mexico        <=50K
# 16               35.0  United-States        <=50K
# 17               40.0  United-States        <=50K
# 18               50.0  United-States        <=50K
# 19               45.0  United-States         >50K
# 20               60.0  United-States         >50K
# 21               20.0  United-States        <=50K
# 22               40.0  United-States        <=50K
# 23               40.0  United-States        <=50K
# 24               40.0  United-States        <=50K
# 25               40.0  United-States         >50K
# 26               40.0  United-States        <=50K
# 27               60.0          South         >50K
# 28               80.0  United-States        <=50K
# 29               40.0  United-States        <=50K
# ...               ...            ...          ...
# 25799            40.0  United-States         >50K
# 25800            40.0  United-States         >50K
# 25801            72.0  United-States        <=50K
# 25802            20.0         Canada         >50K
# 25803            20.0  United-States         >50K
# 25804            40.0         Poland        <=50K
# 25805            20.0  United-States        <=50K
# 25806            99.0  United-States        <=50K
# 25807            45.0  United-States        <=50K
# 25808            50.0  United-States         >50K
# 25809            40.0  United-States         >50K
# 25810            55.0  United-States        <=50K
# 25811            40.0  United-States        <=50K
# 25812            40.0  United-States        <=50K
# 25813            40.0  United-States        <=50K
# 25814            47.0  United-States        <=50K
# 25815            44.0  United-States         >50K
# 25816            40.0          South        <=50K
# 25817            45.0  United-States         >50K
# 25818            40.0  United-States        <=50K
# 25819            45.0  United-States        <=50K
# 25820            40.0  United-States        <=50K
# 25821            28.0  United-States        <=50K
# 25822            72.0  United-States        <=50K
# 25823            40.0  United-States        <=50K
# 25824            45.0  United-States        <=50K
# 25825            60.0  United-States         >50K
# 25826            40.0         Mexico        <=50K
# 25827            40.0  United-States        <=50K
# 25828             NaN            NaN          NaN
#
# [25829 rows x 12 columns]

# %%
train.apply(lambda x: sum(x.isnull()))
# Out:
# ID                   0
# Age                  0
# Workclass         1448
# Education            0
# Marital.Status       0
# Occupation        1454
# Relationship         1
# Race                 1
# Sex                  1
# Hours.Per.Week       1
# Native.Country     464
# Income.Group         1
# dtype: int64

# %%
from scipy.stats import mode

# %%
mode(train.Workclass)[0][0]
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/numpy/lib/arraysetops.py:216: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))
# 'Private'

# %%
train.Workclass
# Out:
# 0               State-gov
# 1        Self-emp-not-inc
# 2                 Private
# 3                 Private
# 4                 Private
# 5                 Private
# 6                 Private
# 7        Self-emp-not-inc
# 8                 Private
# 9                 Private
# 10                Private
# 11              State-gov
# 12                Private
# 13                Private
# 14                Private
# 15                Private
# 16       Self-emp-not-inc
# 17                Private
# 18                Private
# 19       Self-emp-not-inc
# 20                Private
# 21                Private
# 22            Federal-gov
# 23                Private
# 24                Private
# 25              Local-gov
# 26                Private
# 27                    NaN
# 28                Private
# 29                Private
#                ...
# 25799         Federal-gov
# 25800        Self-emp-inc
# 25801             Private
# 25802                 NaN
# 25803             Private
# 25804             Private
# 25805             Private
# 25806                 NaN
# 25807             Private
# 25808             Private
# 25809             Private
# 25810             Private
# 25811           Local-gov
# 25812             Private
# 25813                 NaN
# 25814             Private
# 25815             Private
# 25816             Private
# 25817             Private
# 25818           Local-gov
# 25819                 NaN
# 25820           State-gov
# 25821             Private
# 25822           Local-gov
# 25823             Private
# 25824    Self-emp-not-inc
# 25825             Private
# 25826                 NaN
# 25827           Local-gov
# 25828    Self-emp-not-inc
# Name: Workclass, dtype: object

# %%
train.Workclass[0]
# Out:
# 'State-gov'

# %%
mode(train.Occupation)[0][0]
# Out:
# 'Prof-specialty'

# %%
(train.Occupation)[0]
# Out:
# 'Adm-clerical'

# %%
mode(test.Workclass)
# Out:
# ModeResult(mode=array(['Private'], dtype=object), count=array([11210]))

# %%
test.Workclass
# Out:
# 0                 Private
# 1                 Private
# 2               Local-gov
# 3                 Private
# 4                     NaN
# 5                 Private
# 6                     NaN
# 7        Self-emp-not-inc
# 8                 Private
# 9                 Private
# 10                Private
# 11            Federal-gov
# 12                Private
# 13                    NaN
# 14                Private
# 15                Private
# 16              State-gov
# 17                Private
# 18                Private
# 19                Private
# 20                Private
# 21                Private
# 22                    NaN
# 23                Private
# 24                Private
# 25       Self-emp-not-inc
# 26                Private
# 27                Private
# 28                Private
# 29       Self-emp-not-inc
#                ...
# 16251                 NaN
# 16252             Private
# 16253             Private
# 16254             Private
# 16255           Local-gov
# 16256             Private
# 16257        Self-emp-inc
# 16258             Private
# 16259             Private
# 16260             Private
# 16261             Private
# 16262             Private
# 16263             Private
# 16264    Self-emp-not-inc
# 16265           Local-gov
# 16266             Private
# 16267             Private
# 16268             Private
# 16269             Private
# 16270             Private
# 16271             Private
# 16272             Private
# 16273             Private
# 16274           Local-gov
# 16275             Private
# 16276             Private
# 16277                 NaN
# 16278             Private
# 16279             Private
# 16280        Self-emp-inc
# Name: Workclass, dtype: object

# %%
mode(train.Workclass)[0][0]
# Out:
# 'Private'

# %%
Workclass_Null_Indices = train[train.Workclass.isnull()].index
for el in Workclass_Null_Indices: train.Workclass[el] = 'Private'
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
mode(test.Workclass)[0][0]
# Out:
# 'Private'

# %%
test
# Out:
#           ID  Age         Workclass     Education      Marital.Status  \
# 0      32562   25           Private          11th       Never-married
# 1      32563   38           Private       HS-grad  Married-civ-spouse
# 2      32564   28         Local-gov    Assoc-acdm  Married-civ-spouse
# 3      32565   44           Private  Some-college  Married-civ-spouse
# 4      32566   18               NaN  Some-college       Never-married
# 5      32567   34           Private          10th       Never-married
# 6      32568   29               NaN       HS-grad       Never-married
# 7      32569   63  Self-emp-not-inc   Prof-school  Married-civ-spouse
# 8      32570   24           Private  Some-college       Never-married
# 9      32571   55           Private       7th-8th  Married-civ-spouse
# 10     32572   65           Private       HS-grad  Married-civ-spouse
# 11     32573   36       Federal-gov     Bachelors  Married-civ-spouse
# 12     32574   26           Private       HS-grad       Never-married
# 13     32575   58               NaN       HS-grad  Married-civ-spouse
# 14     32576   48           Private       HS-grad  Married-civ-spouse
# 15     32577   43           Private       Masters  Married-civ-spouse
# 16     32578   20         State-gov  Some-college       Never-married
# 17     32579   43           Private       HS-grad  Married-civ-spouse
# 18     32580   37           Private       HS-grad             Widowed
# 19     32581   40           Private     Doctorate  Married-civ-spouse
# 20     32582   34           Private     Bachelors  Married-civ-spouse
# 21     32583   34           Private  Some-college       Never-married
# 22     32584   72               NaN       7th-8th            Divorced
# 23     32585   25           Private     Bachelors       Never-married
# 24     32586   25           Private     Bachelors  Married-civ-spouse
# 25     32587   45  Self-emp-not-inc       HS-grad  Married-civ-spouse
# 26     32588   22           Private       HS-grad       Never-married
# 27     32589   23           Private       HS-grad           Separated
# 28     32590   54           Private       HS-grad  Married-civ-spouse
# 29     32591   32  Self-emp-not-inc  Some-college       Never-married
# ...      ...  ...               ...           ...                 ...
# 16251  48813   81               NaN     Assoc-voc  Married-civ-spouse
# 16252  48814   60           Private     Assoc-voc  Married-civ-spouse
# 16253  48815   39           Private     Bachelors       Never-married
# 16254  48816   38           Private       Masters  Married-civ-spouse
# 16255  48817   43         Local-gov       Masters  Married-civ-spouse
# 16256  48818   23           Private       HS-grad       Never-married
# 16257  48819   73      Self-emp-inc  Some-college            Divorced
# 16258  48820   35           Private  Some-college  Married-civ-spouse
# 16259  48821   66           Private       HS-grad             Widowed
# 16260  48822   27           Private  Some-college       Never-married
# 16261  48823   40           Private   Prof-school  Married-civ-spouse
# 16262  48824   51           Private       HS-grad  Married-civ-spouse
# 16263  48825   22           Private  Some-college       Never-married
# 16264  48826   64  Self-emp-not-inc       HS-grad             Widowed
# 16265  48827   50         Local-gov       Masters  Married-civ-spouse
# 16266  48828   55           Private       HS-grad           Separated
# 16267  48829   38           Private     Assoc-voc       Never-married
# 16268  48830   58           Private    Assoc-acdm            Divorced
# 16269  48831   32           Private       HS-grad  Married-civ-spouse
# 16270  48832   48           Private       HS-grad  Married-civ-spouse
# 16271  48833   61           Private       HS-grad  Married-civ-spouse
# 16272  48834   31           Private       HS-grad  Married-civ-spouse
# 16273  48835   25           Private       HS-grad       Never-married
# 16274  48836   48         Local-gov       Masters            Divorced
# 16275  48837   33           Private     Bachelors       Never-married
# 16276  48838   39           Private     Bachelors            Divorced
# 16277  48839   64               NaN       HS-grad             Widowed
# 16278  48840   38           Private     Bachelors  Married-civ-spouse
# 16279  48841   44           Private     Bachelors            Divorced
# 16280  48842   35      Self-emp-inc     Bachelors  Married-civ-spouse
#
#               Occupation    Relationship                Race     Sex  \
# 0      Machine-op-inspct       Own-child               Black    Male
# 1        Farming-fishing         Husband               White    Male
# 2        Protective-serv         Husband               White    Male
# 3      Machine-op-inspct         Husband               Black    Male
# 4                    NaN       Own-child               White  Female
# 5          Other-service   Not-in-family               White    Male
# 6                    NaN       Unmarried               Black    Male
# 7         Prof-specialty         Husband               White    Male
# 8          Other-service       Unmarried               White  Female
# 9           Craft-repair         Husband               White    Male
# 10     Machine-op-inspct         Husband               White    Male
# 11          Adm-clerical         Husband               White    Male
# 12          Adm-clerical   Not-in-family               White  Female
# 13                   NaN         Husband               White    Male
# 14     Machine-op-inspct         Husband               White    Male
# 15       Exec-managerial         Husband               White    Male
# 16         Other-service       Own-child               White    Male
# 17          Adm-clerical            Wife               White  Female
# 18     Machine-op-inspct       Unmarried               White  Female
# 19        Prof-specialty         Husband  Asian-Pac-Islander    Male
# 20          Tech-support         Husband               White    Male
# 21         Other-service       Own-child               Black  Female
# 22                   NaN   Not-in-family               White  Female
# 23        Prof-specialty   Not-in-family               White    Male
# 24        Prof-specialty         Husband               White    Male
# 25          Craft-repair         Husband               White    Male
# 26          Adm-clerical       Own-child               White    Male
# 27     Machine-op-inspct       Unmarried               Black    Male
# 28          Craft-repair         Husband               White    Male
# 29        Prof-specialty   Not-in-family               White    Male
# ...                  ...             ...                 ...     ...
# 16251                NaN         Husband               White    Male
# 16252     Prof-specialty         Husband               White    Male
# 16253       Tech-support   Not-in-family               White  Female
# 16254     Prof-specialty         Husband               White    Male
# 16255    Exec-managerial         Husband               White    Male
# 16256  Machine-op-inspct       Own-child               White    Male
# 16257    Exec-managerial   Not-in-family               White  Female
# 16258    Protective-serv         Husband               White    Male
# 16259              Sales  Other-relative               White  Female
# 16260              Sales   Not-in-family               White  Female
# 16261     Prof-specialty         Husband               White    Male
# 16262       Craft-repair         Husband               White    Male
# 16263       Craft-repair       Own-child               White    Male
# 16264    Farming-fishing   Not-in-family               White    Male
# 16265     Prof-specialty            Wife               White  Female
# 16266    Priv-house-serv   Not-in-family               White  Female
# 16267       Adm-clerical       Unmarried               Black  Female
# 16268     Prof-specialty   Not-in-family               White    Male
# 16269  Handlers-cleaners         Husband               White    Male
# 16270       Adm-clerical         Husband               White    Male
# 16271              Sales         Husband               White    Male
# 16272       Craft-repair         Husband               White    Male
# 16273      Other-service       Own-child               White  Female
# 16274      Other-service   Not-in-family               White    Male
# 16275     Prof-specialty       Own-child               White    Male
# 16276     Prof-specialty   Not-in-family               White  Female
# 16277                NaN  Other-relative               Black    Male
# 16278     Prof-specialty         Husband               White    Male
# 16279       Adm-clerical       Own-child  Asian-Pac-Islander    Male
# 16280    Exec-managerial         Husband               White    Male
#
#        Hours.Per.Week Native.Country
# 0                  40  United-States
# 1                  50  United-States
# 2                  40  United-States
# 3                  40  United-States
# 4                  30  United-States
# 5                  30  United-States
# 6                  40  United-States
# 7                  32  United-States
# 8                  40  United-States
# 9                  10  United-States
# 10                 40  United-States
# 11                 40  United-States
# 12                 39  United-States
# 13                 35  United-States
# 14                 48  United-States
# 15                 50  United-States
# 16                 25  United-States
# 17                 30  United-States
# 18                 20  United-States
# 19                 45            NaN
# 20                 47  United-States
# 21                 35  United-States
# 22                  6  United-States
# 23                 43           Peru
# 24                 40  United-States
# 25                 90  United-States
# 26                 20  United-States
# 27                 54  United-States
# 28                 35  United-States
# 29                 60  United-States
# ...               ...            ...
# 16251              20  United-States
# 16252              40  United-States
# 16253              40  United-States
# 16254              50  United-States
# 16255              50  United-States
# 16256              40  United-States
# 16257              40  United-States
# 16258              40  United-States
# 16259               8  United-States
# 16260              45  United-States
# 16261              55  United-States
# 16262              40  United-States
# 16263              40  United-States
# 16264              32  United-States
# 16265              40            NaN
# 16266              32  United-States
# 16267              40  United-States
# 16268              36  United-States
# 16269              40  United-States
# 16270              40  United-States
# 16271              48  United-States
# 16272              40  United-States
# 16273              40  United-States
# 16274              40  United-States
# 16275              40  United-States
# 16276              36  United-States
# 16277              40  United-States
# 16278              50  United-States
# 16279              40  United-States
# 16280              60  United-States
#
# [16281 rows x 11 columns]

# %%
Workclass_Null_Indices_test = test[test.Workclass.isnull()].index
for el in Workclass_Null_Indices_test: test.Workclass[el] = 'Private'
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
Occupation_Null_Indices_train = train[train.Occupation.isnull()].index
for el in Occupation_Null_Indices_train: train.Occupation[el] = 'Prof-specialty'
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
Occupation_Null_Indices_test = test[test.Occupation.isnull()].index
for el in Occupation_Null_Indices_test: test.Occupation[el] = 'Prof-specialty'
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
mode(train['Native.Country'])[0][0]
# Out:
# 'United-States'

# %%
mode(test['Native.Country'])[0][0]
# Out:
# 'United-States'

# %%
NativeCountry_Null_Indices_train = train[train['Native.Country'].isnull()].index
for el in NativeCountry_Null_Indices_train: train['Native.Country'][el] = 'United-States'
    
NativeCountry_Null_Indices_test = test[test['Native.Country'].isnull()].index
for el in NativeCountry_Null_Indices_test: test['Native.Country'][el] = 'United-States'
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.hist(train.Age, bins = 100)
plt.show()
plt.hist(test.Age, bins = 100)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
number = LabelEncoder()

# %%
number
# Out:
# LabelEncoder()

# %%
train.Workclass = number.fit_transform(train.Workclass.astype('str'))

# %%
train.Workclass
# Out:
# 0        6
# 1        5
# 2        3
# 3        3
# 4        3
# 5        3
# 6        3
# 7        5
# 8        3
# 9        3
# 10       3
# 11       6
# 12       3
# 13       3
# 14       3
# 15       3
# 16       5
# 17       3
# 18       3
# 19       5
# 20       3
# 21       3
# 22       0
# 23       3
# 24       3
# 25       1
# 26       3
# 27       8
# 28       3
# 29       3
#         ..
# 25799    0
# 25800    4
# 25801    3
# 25802    8
# 25803    3
# 25804    3
# 25805    3
# 25806    8
# 25807    3
# 25808    3
# 25809    3
# 25810    3
# 25811    1
# 25812    3
# 25813    8
# 25814    3
# 25815    3
# 25816    3
# 25817    3
# 25818    1
# 25819    8
# 25820    6
# 25821    3
# 25822    1
# 25823    3
# 25824    5
# 25825    3
# 25826    8
# 25827    1
# 25828    5
# Name: Workclass, dtype: int64

# %%
typeof(train.Workclass)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b69be0bded3e> in <module>()
# ----> 1 typeof(train.Workclass)
#
# NameError: name 'typeof' is not defined

# %%
test.Workclass = number.fit_transform(test.Workclass.astype('str'))

# %%
fig = plt.figure(figsize=(4,4), dpi=1600)
plt.hist(train.Workclass, bins = len(unique_working_classes))
plt.show()

fig = plt.figure(figsize=(4,4), dpi=1600)
plt.hist(test.Workclass, bins = len(unique_working_classes))
plt.show()

# %%
unique_working_classes = list(train.Workclass.unique())

# %%
education_levels_train = train.Education.unique()
print education_levels_train
# Out:
# ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th' '1st-4th'
#  'Preschool' '12th']

# %%
train.Income.Group
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-afd14ce54e3e> in <module>()
# ----> 1 train.Income.Group
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Income'

# %%
train.Income.Group.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-b2cf41103c85> in <module>()
# ----> 1 train.Income.Group.unique()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Income'

# %%
print train[train['Income.Group'] != '<=50K'].index
# Out:
# Int64Index([    7,     8,     9,    10,    11,    14,    19,    20,    25,
#                27,
#             ...
#             25799, 25800, 25802, 25803, 25808, 25809, 25815, 25817, 25825,
#             25828],
#            dtype='int64', length=6182)

# %%
print train[train['Income.Group'] == '<=50K'].index
# Out:
# Int64Index([    0,     1,     2,     3,     4,     5,     6,    12,    13,
#                15,
#             ...
#             25816, 25818, 25819, 25820, 25821, 25822, 25823, 25824, 25826,
#             25827],
#            dtype='int64', length=19647)

# %%
print train[train['Income.Group'] != '<=50K'].index
# Out:
# Int64Index([    7,     8,     9,    10,    11,    14,    19,    20,    25,
#                27,
#             ...
#             25799, 25800, 25802, 25803, 25808, 25809, 25815, 25817, 25825,
#             25828],
#            dtype='int64', length=6182)

# %%
train['Marital.Status'] = number.fit_transform(train['Marital.Status'])
test['Marital.Status'] = number.fit_transform(test['Marital.Status'])

# %%
new_marital_status_levels = train['Marital.Status'].unique()

# %%
train.Occupation = number.fit_transform(train.Occupation)
test.Occupation = number.fit_transform(test.Occupation)
new_occupation_levels = train.Occupation.unique()
new_occupation_levels
# Out:
# array([ 1,  4,  6, 10,  8, 12,  3, 14,  5,  7, 13,  0, 11,  2,  9])

# %%
train
# Out:
#           ID  Age  Workclass     Education  Marital.Status  Occupation  \
# 0          1   39          6     Bachelors               5           1
# 1          2   50          5     Bachelors               3           4
# 2          3   38          3       HS-grad               0           6
# 3          4   53          3          11th               3           6
# 4          5   28          3     Bachelors               3          10
# 5          6   37          3       Masters               3           4
# 6          7   49          3           9th               4           8
# 7          8   52          5       HS-grad               3           4
# 8          9   31          3       Masters               5          10
# 9         10   42          3     Bachelors               3           4
# 10        11   37          3  Some-college               3           4
# 11        12   30          6     Bachelors               3          10
# 12        13   23          3     Bachelors               5           1
# 13        14   32          3    Assoc-acdm               5          12
# 14        15   40          3     Assoc-voc               3           3
# 15        16   34          3       7th-8th               3          14
# 16        17   25          5       HS-grad               5           5
# 17        18   32          3       HS-grad               5           7
# 18        19   38          3          11th               3          12
# 19        20   43          5       Masters               0           4
# 20        21   40          3     Doctorate               3          10
# 21        22   54          3       HS-grad               6           8
# 22        23   35          0           9th               3           5
# 23        24   43          3          11th               3          14
# 24        25   59          3       HS-grad               0          13
# 25        26   56          1     Bachelors               3          13
# 26        27   19          3       HS-grad               5           3
# 27        28   54          8  Some-college               3           0
# 28        29   39          3       HS-grad               0           4
# 29        30   49          3       HS-grad               3           3
# ...      ...  ...        ...           ...             ...         ...
# 25799  25800   46          0       Masters               3           2
# 25800  25801   54          4  Some-college               3          12
# 25801  25802   34          3       HS-grad               3           3
# 25802  25803   67          8     Doctorate               3           0
# 25803  25804   62          3     Bachelors               3          12
# 25804  25805   30          3  Some-college               3           6
# 25805  25806   19          3       HS-grad               5           8
# 25806  25807   49          8       7th-8th               3           0
# 25807  25808   27          3     Assoc-voc               5           7
# 25808  25809   36          3  Some-college               3           3
# 25809  25810   52          3     Bachelors               3           7
# 25810  25811   47          3          12th               4           4
# 25811  25812   57          1       HS-grad               0          11
# 25812  25813   64          3  Some-college               4           4
# 25813  25814   56          8       HS-grad               0           0
# 25814  25815   53          3          11th               7           8
# 25815  25816   53          3     Bachelors               3           3
# 25816  25817   31          3  Some-college               6          12
# 25817  25818   41          3     Bachelors               3           4
# 25818  25819   45          1       HS-grad               6           8
# 25819  25820   63          8     Bachelors               3           0
# 25820  25821   45          6       HS-grad               0           1
# 25821  25822   23          3  Some-college               5           8
# 25822  25823   39          1       Masters               3          10
# 25823  25824   31          3     Assoc-voc               3           4
# 25824  25825   35          5     Bachelors               3           5
# 25825  25826   54          3       Masters               3          14
# 25826  25827   22          8  Some-college               5           0
# 25827  25828   40          1     Bachelors               0          10
# 25828  25829   55          5     Bachelors               2           0
#
#          Relationship                Race     Sex  Hours.Per.Week  \
# 0       Not-in-family               White    Male            40.0
# 1             Husband               White    Male            13.0
# 2       Not-in-family               White    Male            40.0
# 3             Husband               Black    Male            40.0
# 4                Wife               Black  Female            40.0
# 5                Wife               White  Female            40.0
# 6       Not-in-family               Black  Female            16.0
# 7             Husband               White    Male            45.0
# 8       Not-in-family               White  Female            50.0
# 9             Husband               White    Male            40.0
# 10            Husband               Black    Male            80.0
# 11            Husband  Asian-Pac-Islander    Male            40.0
# 12          Own-child               White  Female            30.0
# 13      Not-in-family               Black    Male            50.0
# 14            Husband  Asian-Pac-Islander    Male            40.0
# 15            Husband  Amer-Indian-Eskimo    Male            45.0
# 16          Own-child               White    Male            35.0
# 17          Unmarried               White    Male            40.0
# 18            Husband               White    Male            50.0
# 19          Unmarried               White  Female            45.0
# 20            Husband               White    Male            60.0
# 21          Unmarried               Black  Female            20.0
# 22            Husband               Black    Male            40.0
# 23            Husband               White    Male            40.0
# 24          Unmarried               White  Female            40.0
# 25            Husband               White    Male            40.0
# 26          Own-child               White    Male            40.0
# 27            Husband  Asian-Pac-Islander    Male            60.0
# 28      Not-in-family               White    Male            80.0
# 29            Husband               White    Male            40.0
# ...               ...                 ...     ...             ...
# 25799         Husband               White    Male            40.0
# 25800         Husband               White    Male            40.0
# 25801         Husband               White    Male            72.0
# 25802         Husband               White    Male            20.0
# 25803         Husband               White    Male            20.0
# 25804         Husband               White    Male            40.0
# 25805       Own-child               White    Male            20.0
# 25806         Husband               White    Male            99.0
# 25807       Unmarried               White    Male            45.0
# 25808         Husband               White    Male            50.0
# 25809         Husband               White    Male            40.0
# 25810   Not-in-family               White  Female            55.0
# 25811   Not-in-family               White  Female            40.0
# 25812       Unmarried               White  Female            40.0
# 25813   Not-in-family               White    Male            40.0
# 25814       Own-child               White  Female            47.0
# 25815         Husband               White    Male            44.0
# 25816       Unmarried  Asian-Pac-Islander    Male            40.0
# 25817         Husband               White    Male            45.0
# 25818       Unmarried               Black  Female            40.0
# 25819         Husband               White    Male            45.0
# 25820  Other-relative               White  Female            40.0
# 25821   Not-in-family               White  Female            28.0
# 25822         Husband               White    Male            72.0
# 25823         Husband               White    Male            40.0
# 25824         Husband               White    Male            45.0
# 25825         Husband               White    Male            60.0
# 25826       Own-child               White  Female            40.0
# 25827       Unmarried               White  Female            40.0
# 25828             NaN                 NaN     NaN             NaN
#
#       Native.Country Income.Group
# 0      United-States        <=50K
# 1      United-States        <=50K
# 2      United-States        <=50K
# 3      United-States        <=50K
# 4               Cuba        <=50K
# 5      United-States        <=50K
# 6            Jamaica        <=50K
# 7      United-States         >50K
# 8      United-States         >50K
# 9      United-States         >50K
# 10     United-States         >50K
# 11             India         >50K
# 12     United-States        <=50K
# 13     United-States        <=50K
# 14     United-States         >50K
# 15            Mexico        <=50K
# 16     United-States        <=50K
# 17     United-States        <=50K
# 18     United-States        <=50K
# 19     United-States         >50K
# 20     United-States         >50K
# 21     United-States        <=50K
# 22     United-States        <=50K
# 23     United-States        <=50K
# 24     United-States        <=50K
# 25     United-States         >50K
# 26     United-States        <=50K
# 27             South         >50K
# 28     United-States        <=50K
# 29     United-States        <=50K
# ...              ...          ...
# 25799  United-States         >50K
# 25800  United-States         >50K
# 25801  United-States        <=50K
# 25802         Canada         >50K
# 25803  United-States         >50K
# 25804         Poland        <=50K
# 25805  United-States        <=50K
# 25806  United-States        <=50K
# 25807  United-States        <=50K
# 25808  United-States         >50K
# 25809  United-States         >50K
# 25810  United-States        <=50K
# 25811  United-States        <=50K
# 25812  United-States        <=50K
# 25813  United-States        <=50K
# 25814  United-States        <=50K
# 25815  United-States         >50K
# 25816          South        <=50K
# 25817  United-States         >50K
# 25818  United-States        <=50K
# 25819  United-States        <=50K
# 25820  United-States        <=50K
# 25821  United-States        <=50K
# 25822  United-States        <=50K
# 25823  United-States        <=50K
# 25824  United-States        <=50K
# 25825  United-States         >50K
# 25826         Mexico        <=50K
# 25827  United-States        <=50K
# 25828  United-States          NaN
#
# [25829 rows x 12 columns]

# %%
train.Relationship = number.fit_transform(train.Relationship)
test.Relationship = number.fit_transform(test.Relationship)

# %%
train.Race = number.fit_transform(train.Race)
test.Race = number.fit_transform(test.Race)
new_race_levels = train.Race.unique()
print new_race_levels
# Out:
# [5 3 2 1 4 0]

# %%
sex_levels = train.Sex.unique()
train.Sex = number.fit_transform(train.Sex)
test.Sex = number.fit_transform(test.Sex)
new_sex_levels = train.Sex.unique()
sex_levels_decoder = dict(zip(new_sex_levels, sex_levels))
sex_levels_decoder
# Out:
# {0: nan, 1: 'Female', 2: 'Male'}

# %%
train.Sex
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        1
# 5        1
# 6        1
# 7        2
# 8        1
# 9        2
# 10       2
# 11       2
# 12       1
# 13       2
# 14       2
# 15       2
# 16       2
# 17       2
# 18       2
# 19       1
# 20       2
# 21       1
# 22       2
# 23       2
# 24       1
# 25       2
# 26       2
# 27       2
# 28       2
# 29       2
#         ..
# 25799    2
# 25800    2
# 25801    2
# 25802    2
# 25803    2
# 25804    2
# 25805    2
# 25806    2
# 25807    2
# 25808    2
# 25809    2
# 25810    1
# 25811    1
# 25812    1
# 25813    2
# 25814    1
# 25815    2
# 25816    2
# 25817    2
# 25818    1
# 25819    2
# 25820    1
# 25821    1
# 25822    2
# 25823    2
# 25824    2
# 25825    2
# 25826    1
# 25827    1
# 25828    0
# Name: Sex, dtype: int64

# %%
native_country_levels = train['Native.Country'].unique()
train['Native.Country'] = number.fit_transform(train['Native.Country'])
test['Native.Country'] = number.fit_transform(test['Native.Country'])
new_native_country_levels = train['Native.Country'].unique()
native_country_levels_decoder = dict(zip(new_native_country_levels, native_country_levels))

# %%
train
# Out:
#           ID  Age  Workclass     Education  Marital.Status  Occupation  \
# 0          1   39          6     Bachelors               5           1
# 1          2   50          5     Bachelors               3           4
# 2          3   38          3       HS-grad               0           6
# 3          4   53          3          11th               3           6
# 4          5   28          3     Bachelors               3          10
# 5          6   37          3       Masters               3           4
# 6          7   49          3           9th               4           8
# 7          8   52          5       HS-grad               3           4
# 8          9   31          3       Masters               5          10
# 9         10   42          3     Bachelors               3           4
# 10        11   37          3  Some-college               3           4
# 11        12   30          6     Bachelors               3          10
# 12        13   23          3     Bachelors               5           1
# 13        14   32          3    Assoc-acdm               5          12
# 14        15   40          3     Assoc-voc               3           3
# 15        16   34          3       7th-8th               3          14
# 16        17   25          5       HS-grad               5           5
# 17        18   32          3       HS-grad               5           7
# 18        19   38          3          11th               3          12
# 19        20   43          5       Masters               0           4
# 20        21   40          3     Doctorate               3          10
# 21        22   54          3       HS-grad               6           8
# 22        23   35          0           9th               3           5
# 23        24   43          3          11th               3          14
# 24        25   59          3       HS-grad               0          13
# 25        26   56          1     Bachelors               3          13
# 26        27   19          3       HS-grad               5           3
# 27        28   54          8  Some-college               3           0
# 28        29   39          3       HS-grad               0           4
# 29        30   49          3       HS-grad               3           3
# ...      ...  ...        ...           ...             ...         ...
# 25799  25800   46          0       Masters               3           2
# 25800  25801   54          4  Some-college               3          12
# 25801  25802   34          3       HS-grad               3           3
# 25802  25803   67          8     Doctorate               3           0
# 25803  25804   62          3     Bachelors               3          12
# 25804  25805   30          3  Some-college               3           6
# 25805  25806   19          3       HS-grad               5           8
# 25806  25807   49          8       7th-8th               3           0
# 25807  25808   27          3     Assoc-voc               5           7
# 25808  25809   36          3  Some-college               3           3
# 25809  25810   52          3     Bachelors               3           7
# 25810  25811   47          3          12th               4           4
# 25811  25812   57          1       HS-grad               0          11
# 25812  25813   64          3  Some-college               4           4
# 25813  25814   56          8       HS-grad               0           0
# 25814  25815   53          3          11th               7           8
# 25815  25816   53          3     Bachelors               3           3
# 25816  25817   31          3  Some-college               6          12
# 25817  25818   41          3     Bachelors               3           4
# 25818  25819   45          1       HS-grad               6           8
# 25819  25820   63          8     Bachelors               3           0
# 25820  25821   45          6       HS-grad               0           1
# 25821  25822   23          3  Some-college               5           8
# 25822  25823   39          1       Masters               3          10
# 25823  25824   31          3     Assoc-voc               3           4
# 25824  25825   35          5     Bachelors               3           5
# 25825  25826   54          3       Masters               3          14
# 25826  25827   22          8  Some-college               5           0
# 25827  25828   40          1     Bachelors               0          10
# 25828  25829   55          5     Bachelors               2           0
#
#        Relationship  Race  Sex  Hours.Per.Week  Native.Country Income.Group
# 0                 2     5    2            40.0              38        <=50K
# 1                 1     5    2            13.0              38        <=50K
# 2                 2     5    2            40.0              38        <=50K
# 3                 1     3    2            40.0              38        <=50K
# 4                 6     3    1            40.0               4        <=50K
# 5                 6     5    1            40.0              38        <=50K
# 6                 2     3    1            16.0              22        <=50K
# 7                 1     5    2            45.0              38         >50K
# 8                 2     5    1            50.0              38         >50K
# 9                 1     5    2            40.0              38         >50K
# 10                1     3    2            80.0              38         >50K
# 11                1     2    2            40.0              18         >50K
# 12                4     5    1            30.0              38        <=50K
# 13                2     3    2            50.0              38        <=50K
# 14                1     2    2            40.0              38         >50K
# 15                1     1    2            45.0              25        <=50K
# 16                4     5    2            35.0              38        <=50K
# 17                5     5    2            40.0              38        <=50K
# 18                1     5    2            50.0              38        <=50K
# 19                5     5    1            45.0              38         >50K
# 20                1     5    2            60.0              38         >50K
# 21                5     3    1            20.0              38        <=50K
# 22                1     3    2            40.0              38        <=50K
# 23                1     5    2            40.0              38        <=50K
# 24                5     5    1            40.0              38        <=50K
# 25                1     5    2            40.0              38         >50K
# 26                4     5    2            40.0              38        <=50K
# 27                1     2    2            60.0              34         >50K
# 28                2     5    2            80.0              38        <=50K
# 29                1     5    2            40.0              38        <=50K
# ...             ...   ...  ...             ...             ...          ...
# 25799             1     5    2            40.0              38         >50K
# 25800             1     5    2            40.0              38         >50K
# 25801             1     5    2            72.0              38        <=50K
# 25802             1     5    2            20.0               1         >50K
# 25803             1     5    2            20.0              38         >50K
# 25804             1     5    2            40.0              30        <=50K
# 25805             4     5    2            20.0              38        <=50K
# 25806             1     5    2            99.0              38        <=50K
# 25807             5     5    2            45.0              38        <=50K
# 25808             1     5    2            50.0              38         >50K
# 25809             1     5    2            40.0              38         >50K
# 25810             2     5    1            55.0              38        <=50K
# 25811             2     5    1            40.0              38        <=50K
# 25812             5     5    1            40.0              38        <=50K
# 25813             2     5    2            40.0              38        <=50K
# 25814             4     5    1            47.0              38        <=50K
# 25815             1     5    2            44.0              38         >50K
# 25816             5     2    2            40.0              34        <=50K
# 25817             1     5    2            45.0              38         >50K
# 25818             5     3    1            40.0              38        <=50K
# 25819             1     5    2            45.0              38        <=50K
# 25820             3     5    1            40.0              38        <=50K
# 25821             2     5    1            28.0              38        <=50K
# 25822             1     5    2            72.0              38        <=50K
# 25823             1     5    2            40.0              38        <=50K
# 25824             1     5    2            45.0              38        <=50K
# 25825             1     5    2            60.0              38         >50K
# 25826             4     5    1            40.0              25        <=50K
# 25827             5     5    1            40.0              38        <=50K
# 25828             0     0    0             NaN              38          NaN
#
# [25829 rows x 12 columns]

# %%
sex_income_crosstab = pd.crosstab(train.Sex, train['Income.Group'], margins = True)
print sex_income_crosstab
# Out:
# Income.Group  <=50K  >50K    All
# Sex
# 1              7620   925   8545
# 2             12027  5256  17283
# All           19647  6181  25828

# %%
train
# Out:
#           ID  Age  Workclass     Education  Marital.Status  Occupation  \
# 0          1   39          6     Bachelors               5           1
# 1          2   50          5     Bachelors               3           4
# 2          3   38          3       HS-grad               0           6
# 3          4   53          3          11th               3           6
# 4          5   28          3     Bachelors               3          10
# 5          6   37          3       Masters               3           4
# 6          7   49          3           9th               4           8
# 7          8   52          5       HS-grad               3           4
# 8          9   31          3       Masters               5          10
# 9         10   42          3     Bachelors               3           4
# 10        11   37          3  Some-college               3           4
# 11        12   30          6     Bachelors               3          10
# 12        13   23          3     Bachelors               5           1
# 13        14   32          3    Assoc-acdm               5          12
# 14        15   40          3     Assoc-voc               3           3
# 15        16   34          3       7th-8th               3          14
# 16        17   25          5       HS-grad               5           5
# 17        18   32          3       HS-grad               5           7
# 18        19   38          3          11th               3          12
# 19        20   43          5       Masters               0           4
# 20        21   40          3     Doctorate               3          10
# 21        22   54          3       HS-grad               6           8
# 22        23   35          0           9th               3           5
# 23        24   43          3          11th               3          14
# 24        25   59          3       HS-grad               0          13
# 25        26   56          1     Bachelors               3          13
# 26        27   19          3       HS-grad               5           3
# 27        28   54          8  Some-college               3           0
# 28        29   39          3       HS-grad               0           4
# 29        30   49          3       HS-grad               3           3
# ...      ...  ...        ...           ...             ...         ...
# 25799  25800   46          0       Masters               3           2
# 25800  25801   54          4  Some-college               3          12
# 25801  25802   34          3       HS-grad               3           3
# 25802  25803   67          8     Doctorate               3           0
# 25803  25804   62          3     Bachelors               3          12
# 25804  25805   30          3  Some-college               3           6
# 25805  25806   19          3       HS-grad               5           8
# 25806  25807   49          8       7th-8th               3           0
# 25807  25808   27          3     Assoc-voc               5           7
# 25808  25809   36          3  Some-college               3           3
# 25809  25810   52          3     Bachelors               3           7
# 25810  25811   47          3          12th               4           4
# 25811  25812   57          1       HS-grad               0          11
# 25812  25813   64          3  Some-college               4           4
# 25813  25814   56          8       HS-grad               0           0
# 25814  25815   53          3          11th               7           8
# 25815  25816   53          3     Bachelors               3           3
# 25816  25817   31          3  Some-college               6          12
# 25817  25818   41          3     Bachelors               3           4
# 25818  25819   45          1       HS-grad               6           8
# 25819  25820   63          8     Bachelors               3           0
# 25820  25821   45          6       HS-grad               0           1
# 25821  25822   23          3  Some-college               5           8
# 25822  25823   39          1       Masters               3          10
# 25823  25824   31          3     Assoc-voc               3           4
# 25824  25825   35          5     Bachelors               3           5
# 25825  25826   54          3       Masters               3          14
# 25826  25827   22          8  Some-college               5           0
# 25827  25828   40          1     Bachelors               0          10
# 25828  25829   55          5     Bachelors               2           0
#
#        Relationship  Race  Sex  Hours.Per.Week  Native.Country Income.Group
# 0                 2     5    2            40.0              38        <=50K
# 1                 1     5    2            13.0              38        <=50K
# 2                 2     5    2            40.0              38        <=50K
# 3                 1     3    2            40.0              38        <=50K
# 4                 6     3    1            40.0               4        <=50K
# 5                 6     5    1            40.0              38        <=50K
# 6                 2     3    1            16.0              22        <=50K
# 7                 1     5    2            45.0              38         >50K
# 8                 2     5    1            50.0              38         >50K
# 9                 1     5    2            40.0              38         >50K
# 10                1     3    2            80.0              38         >50K
# 11                1     2    2            40.0              18         >50K
# 12                4     5    1            30.0              38        <=50K
# 13                2     3    2            50.0              38        <=50K
# 14                1     2    2            40.0              38         >50K
# 15                1     1    2            45.0              25        <=50K
# 16                4     5    2            35.0              38        <=50K
# 17                5     5    2            40.0              38        <=50K
# 18                1     5    2            50.0              38        <=50K
# 19                5     5    1            45.0              38         >50K
# 20                1     5    2            60.0              38         >50K
# 21                5     3    1            20.0              38        <=50K
# 22                1     3    2            40.0              38        <=50K
# 23                1     5    2            40.0              38        <=50K
# 24                5     5    1            40.0              38        <=50K
# 25                1     5    2            40.0              38         >50K
# 26                4     5    2            40.0              38        <=50K
# 27                1     2    2            60.0              34         >50K
# 28                2     5    2            80.0              38        <=50K
# 29                1     5    2            40.0              38        <=50K
# ...             ...   ...  ...             ...             ...          ...
# 25799             1     5    2            40.0              38         >50K
# 25800             1     5    2            40.0              38         >50K
# 25801             1     5    2            72.0              38        <=50K
# 25802             1     5    2            20.0               1         >50K
# 25803             1     5    2            20.0              38         >50K
# 25804             1     5    2            40.0              30        <=50K
# 25805             4     5    2            20.0              38        <=50K
# 25806             1     5    2            99.0              38        <=50K
# 25807             5     5    2            45.0              38        <=50K
# 25808             1     5    2            50.0              38         >50K
# 25809             1     5    2            40.0              38         >50K
# 25810             2     5    1            55.0              38        <=50K
# 25811             2     5    1            40.0              38        <=50K
# 25812             5     5    1            40.0              38        <=50K
# 25813             2     5    2            40.0              38        <=50K
# 25814             4     5    1            47.0              38        <=50K
# 25815             1     5    2            44.0              38         >50K
# 25816             5     2    2            40.0              34        <=50K
# 25817             1     5    2            45.0              38         >50K
# 25818             5     3    1            40.0              38        <=50K
# 25819             1     5    2            45.0              38        <=50K
# 25820             3     5    1            40.0              38        <=50K
# 25821             2     5    1            28.0              38        <=50K
# 25822             1     5    2            72.0              38        <=50K
# 25823             1     5    2            40.0              38        <=50K
# 25824             1     5    2            45.0              38        <=50K
# 25825             1     5    2            60.0              38         >50K
# 25826             4     5    1            40.0              25        <=50K
# 25827             5     5    1            40.0              38        <=50K
# 25828             0     0    0             NaN              38          NaN
#
# [25829 rows x 12 columns]

# %%
train.Education = number.fit_transform(train.Education)
new_education_levels = train.Education.unique()
education_levels_decoder = dict(zip(education_levels_train, new_education_levels))
pprint(education_levels_decoder)
plt.hist(train.Education, bins = len(new_education_levels))
plt.show()

test.Education = number.fit_transform(test.Education)
plt.hist(test.Education, bins = len(new_education_levels))
plt.show()
# Out:
# {'10th': 0,
#  '11th': 1,
#  '12th': 2,
#  '1st-4th': 3,
#  '5th-6th': 4,
#  '7th-8th': 5,
#  '9th': 6,
#  'Assoc-acdm': 7,
#  'Assoc-voc': 8,
#  'Bachelors': 9,
#  'Doctorate': 10,
#  'HS-grad': 11,
#  'Masters': 12,
#  'Preschool': 13,
#  'Prof-school': 14,
#  'Some-college': 15}

# %%
train
# Out:
#           ID  Age  Workclass  Education  Marital.Status  Occupation  \
# 0          1   39          6          9               5           1
# 1          2   50          5          9               3           4
# 2          3   38          3         11               0           6
# 3          4   53          3          1               3           6
# 4          5   28          3          9               3          10
# 5          6   37          3         12               3           4
# 6          7   49          3          6               4           8
# 7          8   52          5         11               3           4
# 8          9   31          3         12               5          10
# 9         10   42          3          9               3           4
# 10        11   37          3         15               3           4
# 11        12   30          6          9               3          10
# 12        13   23          3          9               5           1
# 13        14   32          3          7               5          12
# 14        15   40          3          8               3           3
# 15        16   34          3          5               3          14
# 16        17   25          5         11               5           5
# 17        18   32          3         11               5           7
# 18        19   38          3          1               3          12
# 19        20   43          5         12               0           4
# 20        21   40          3         10               3          10
# 21        22   54          3         11               6           8
# 22        23   35          0          6               3           5
# 23        24   43          3          1               3          14
# 24        25   59          3         11               0          13
# 25        26   56          1          9               3          13
# 26        27   19          3         11               5           3
# 27        28   54          8         15               3           0
# 28        29   39          3         11               0           4
# 29        30   49          3         11               3           3
# ...      ...  ...        ...        ...             ...         ...
# 25799  25800   46          0         12               3           2
# 25800  25801   54          4         15               3          12
# 25801  25802   34          3         11               3           3
# 25802  25803   67          8         10               3           0
# 25803  25804   62          3          9               3          12
# 25804  25805   30          3         15               3           6
# 25805  25806   19          3         11               5           8
# 25806  25807   49          8          5               3           0
# 25807  25808   27          3          8               5           7
# 25808  25809   36          3         15               3           3
# 25809  25810   52          3          9               3           7
# 25810  25811   47          3          2               4           4
# 25811  25812   57          1         11               0          11
# 25812  25813   64          3         15               4           4
# 25813  25814   56          8         11               0           0
# 25814  25815   53          3          1               7           8
# 25815  25816   53          3          9               3           3
# 25816  25817   31          3         15               6          12
# 25817  25818   41          3          9               3           4
# 25818  25819   45          1         11               6           8
# 25819  25820   63          8          9               3           0
# 25820  25821   45          6         11               0           1
# 25821  25822   23          3         15               5           8
# 25822  25823   39          1         12               3          10
# 25823  25824   31          3          8               3           4
# 25824  25825   35          5          9               3           5
# 25825  25826   54          3         12               3          14
# 25826  25827   22          8         15               5           0
# 25827  25828   40          1          9               0          10
# 25828  25829   55          5          9               2           0
#
#        Relationship  Race  Sex  Hours.Per.Week  Native.Country Income.Group
# 0                 2     5    2            40.0              38        <=50K
# 1                 1     5    2            13.0              38        <=50K
# 2                 2     5    2            40.0              38        <=50K
# 3                 1     3    2            40.0              38        <=50K
# 4                 6     3    1            40.0               4        <=50K
# 5                 6     5    1            40.0              38        <=50K
# 6                 2     3    1            16.0              22        <=50K
# 7                 1     5    2            45.0              38         >50K
# 8                 2     5    1            50.0              38         >50K
# 9                 1     5    2            40.0              38         >50K
# 10                1     3    2            80.0              38         >50K
# 11                1     2    2            40.0              18         >50K
# 12                4     5    1            30.0              38        <=50K
# 13                2     3    2            50.0              38        <=50K
# 14                1     2    2            40.0              38         >50K
# 15                1     1    2            45.0              25        <=50K
# 16                4     5    2            35.0              38        <=50K
# 17                5     5    2            40.0              38        <=50K
# 18                1     5    2            50.0              38        <=50K
# 19                5     5    1            45.0              38         >50K
# 20                1     5    2            60.0              38         >50K
# 21                5     3    1            20.0              38        <=50K
# 22                1     3    2            40.0              38        <=50K
# 23                1     5    2            40.0              38        <=50K
# 24                5     5    1            40.0              38        <=50K
# 25                1     5    2            40.0              38         >50K
# 26                4     5    2            40.0              38        <=50K
# 27                1     2    2            60.0              34         >50K
# 28                2     5    2            80.0              38        <=50K
# 29                1     5    2            40.0              38        <=50K
# ...             ...   ...  ...             ...             ...          ...
# 25799             1     5    2            40.0              38         >50K
# 25800             1     5    2            40.0              38         >50K
# 25801             1     5    2            72.0              38        <=50K
# 25802             1     5    2            20.0               1         >50K
# 25803             1     5    2            20.0              38         >50K
# 25804             1     5    2            40.0              30        <=50K
# 25805             4     5    2            20.0              38        <=50K
# 25806             1     5    2            99.0              38        <=50K
# 25807             5     5    2            45.0              38        <=50K
# 25808             1     5    2            50.0              38         >50K
# 25809             1     5    2            40.0              38         >50K
# 25810             2     5    1            55.0              38        <=50K
# 25811             2     5    1            40.0              38        <=50K
# 25812             5     5    1            40.0              38        <=50K
# 25813             2     5    2            40.0              38        <=50K
# 25814             4     5    1            47.0              38        <=50K
# 25815             1     5    2            44.0              38         >50K
# 25816             5     2    2            40.0              34        <=50K
# 25817             1     5    2            45.0              38         >50K
# 25818             5     3    1            40.0              38        <=50K
# 25819             1     5    2            45.0              38        <=50K
# 25820             3     5    1            40.0              38        <=50K
# 25821             2     5    1            28.0              38        <=50K
# 25822             1     5    2            72.0              38        <=50K
# 25823             1     5    2            40.0              38        <=50K
# 25824             1     5    2            45.0              38        <=50K
# 25825             1     5    2            60.0              38         >50K
# 25826             4     5    1            40.0              25        <=50K
# 25827             5     5    1            40.0              38        <=50K
# 25828             0     0    0             NaN              38          NaN
#
# [25829 rows x 12 columns]

# %%
#### predictive modeling

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dependent_variable = 'Income.Group'
independent_variable = [x for x in train.columns if x not in ['ID', dependent_variable]]

# %%
dependent_variable
# Out:
# 'Income.Group'

# %%
independent_variable
# Out:
# ['Age',
#  'Workclass',
#  'Education',
#  'Marital.Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Hours.Per.Week',
#  'Native.Country']

# %%
# Inititate the algorithm
model_01 = DecisionTreeClassifier(max_depth = 10, min_samples_leaf = 100, max_features= 'sqrt')

# %%
model_01
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=100,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
# Fit the algorithm
model_01.fit(train[independent_variable], train[dependent_variable])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-e755dbc04e92> in <module>()
#       1 # Fit the algorithm
# ----> 2 model_01.fit(train[independent_variable], train[dependent_variable])
#
# /usr/local/lib/python2.7/dist-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     737             sample_weight=sample_weight,
#     738             check_input=check_input,
# --> 739             X_idx_sorted=X_idx_sorted)
#     740         return self
#     741
#
# /usr/local/lib/python2.7/dist-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     120         random_state = check_random_state(self.random_state)
#     121         if check_input:
# --> 122             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     123             y = check_array(y, ensure_2d=False, dtype=None)
#     124             if issparse(X):
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.pyc in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
train[independent_variable]
# Out:
#        Age  Workclass  Education  Marital.Status  Occupation  Relationship  \
# 0       39          6          9               5           1             2
# 1       50          5          9               3           4             1
# 2       38          3         11               0           6             2
# 3       53          3          1               3           6             1
# 4       28          3          9               3          10             6
# 5       37          3         12               3           4             6
# 6       49          3          6               4           8             2
# 7       52          5         11               3           4             1
# 8       31          3         12               5          10             2
# 9       42          3          9               3           4             1
# 10      37          3         15               3           4             1
# 11      30          6          9               3          10             1
# 12      23          3          9               5           1             4
# 13      32          3          7               5          12             2
# 14      40          3          8               3           3             1
# 15      34          3          5               3          14             1
# 16      25          5         11               5           5             4
# 17      32          3         11               5           7             5
# 18      38          3          1               3          12             1
# 19      43          5         12               0           4             5
# 20      40          3         10               3          10             1
# 21      54          3         11               6           8             5
# 22      35          0          6               3           5             1
# 23      43          3          1               3          14             1
# 24      59          3         11               0          13             5
# 25      56          1          9               3          13             1
# 26      19          3         11               5           3             4
# 27      54          8         15               3           0             1
# 28      39          3         11               0           4             2
# 29      49          3         11               3           3             1
# ...    ...        ...        ...             ...         ...           ...
# 25799   46          0         12               3           2             1
# 25800   54          4         15               3          12             1
# 25801   34          3         11               3           3             1
# 25802   67          8         10               3           0             1
# 25803   62          3          9               3          12             1
# 25804   30          3         15               3           6             1
# 25805   19          3         11               5           8             4
# 25806   49          8          5               3           0             1
# 25807   27          3          8               5           7             5
# 25808   36          3         15               3           3             1
# 25809   52          3          9               3           7             1
# 25810   47          3          2               4           4             2
# 25811   57          1         11               0          11             2
# 25812   64          3         15               4           4             5
# 25813   56          8         11               0           0             2
# 25814   53          3          1               7           8             4
# 25815   53          3          9               3           3             1
# 25816   31          3         15               6          12             5
# 25817   41          3          9               3           4             1
# 25818   45          1         11               6           8             5
# 25819   63          8          9               3           0             1
# 25820   45          6         11               0           1             3
# 25821   23          3         15               5           8             2
# 25822   39          1         12               3          10             1
# 25823   31          3          8               3           4             1
# 25824   35          5          9               3           5             1
# 25825   54          3         12               3          14             1
# 25826   22          8         15               5           0             4
# 25827   40          1          9               0          10             5
# 25828   55          5          9               2           0             0
#
#        Race  Sex  Hours.Per.Week  Native.Country
# 0         5    2            40.0              38
# 1         5    2            13.0              38
# 2         5    2            40.0              38
# 3         3    2            40.0              38
# 4         3    1            40.0               4
# 5         5    1            40.0              38
# 6         3    1            16.0              22
# 7         5    2            45.0              38
# 8         5    1            50.0              38
# 9         5    2            40.0              38
# 10        3    2            80.0              38
# 11        2    2            40.0              18
# 12        5    1            30.0              38
# 13        3    2            50.0              38
# 14        2    2            40.0              38
# 15        1    2            45.0              25
# 16        5    2            35.0              38
# 17        5    2            40.0              38
# 18        5    2            50.0              38
# 19        5    1            45.0              38
# 20        5    2            60.0              38
# 21        3    1            20.0              38
# 22        3    2            40.0              38
# 23        5    2            40.0              38
# 24        5    1            40.0              38
# 25        5    2            40.0              38
# 26        5    2            40.0              38
# 27        2    2            60.0              34
# 28        5    2            80.0              38
# 29        5    2            40.0              38
# ...     ...  ...             ...             ...
# 25799     5    2            40.0              38
# 25800     5    2            40.0              38
# 25801     5    2            72.0              38
# 25802     5    2            20.0               1
# 25803     5    2            20.0              38
# 25804     5    2            40.0              30
# 25805     5    2            20.0              38
# 25806     5    2            99.0              38
# 25807     5    2            45.0              38
# 25808     5    2            50.0              38
# 25809     5    2            40.0              38
# 25810     5    1            55.0              38
# 25811     5    1            40.0              38
# 25812     5    1            40.0              38
# 25813     5    2            40.0              38
# 25814     5    1            47.0              38
# 25815     5    2            44.0              38
# 25816     2    2            40.0              34
# 25817     5    2            45.0              38
# 25818     3    1            40.0              38
# 25819     5    2            45.0              38
# 25820     5    1            40.0              38
# 25821     5    1            28.0              38
# 25822     5    2            72.0              38
# 25823     5    2            40.0              38
# 25824     5    2            45.0              38
# 25825     5    2            60.0              38
# 25826     5    1            40.0              25
# 25827     5    1            40.0              38
# 25828     0    0             NaN              38
#
# [25829 rows x 10 columns]

# %%
train.Sex.unique()
# Out:
# array([2, 1, 0])

# %%
train['Marital.Status'].unique()
# Out:
# array([5, 3, 0, 4, 6, 1, 7, 2])

# %%
test
# Out:
#           ID  Age  Workclass  Education  Marital.Status  Occupation  \
# 0      32562   25          3          1               4           7
# 1      32563   38          3         11               2           5
# 2      32564   28          1          7               2          11
# 3      32565   44          3         15               2           7
# 4      32566   18          8         15               4           0
# 5      32567   34          3          0               4           8
# 6      32568   29          8         11               4           0
# 7      32569   63          5         14               2          10
# 8      32570   24          3         15               4           8
# 9      32571   55          3          5               2           3
# 10     32572   65          3         11               2           7
# 11     32573   36          0          9               2           1
# 12     32574   26          3         11               4           1
# 13     32575   58          8         11               2           0
# 14     32576   48          3         11               2           7
# 15     32577   43          3         12               2           4
# 16     32578   20          6         15               4           8
# 17     32579   43          3         11               2           1
# 18     32580   37          3         11               6           7
# 19     32581   40          3         10               2          10
# 20     32582   34          3          9               2          13
# 21     32583   34          3         15               4           8
# 22     32584   72          8          5               0           0
# 23     32585   25          3          9               4          10
# 24     32586   25          3          9               2          10
# 25     32587   45          5         11               2           3
# 26     32588   22          3         11               4           1
# 27     32589   23          3         11               5           7
# 28     32590   54          3         11               2           3
# 29     32591   32          5         15               4          10
# ...      ...  ...        ...        ...             ...         ...
# 16251  48813   81          8          8               2           0
# 16252  48814   60          3          8               2          10
# 16253  48815   39          3          9               4          13
# 16254  48816   38          3         12               2          10
# 16255  48817   43          1         12               2           4
# 16256  48818   23          3         11               4           7
# 16257  48819   73          4         15               0           4
# 16258  48820   35          3         15               2          11
# 16259  48821   66          3         11               6          12
# 16260  48822   27          3         15               4          12
# 16261  48823   40          3         14               2          10
# 16262  48824   51          3         11               2           3
# 16263  48825   22          3         15               4           3
# 16264  48826   64          5         11               6           5
# 16265  48827   50          1         12               2          10
# 16266  48828   55          3         11               5           9
# 16267  48829   38          3          8               4           1
# 16268  48830   58          3          7               0          10
# 16269  48831   32          3         11               2           6
# 16270  48832   48          3         11               2           1
# 16271  48833   61          3         11               2          12
# 16272  48834   31          3         11               2           3
# 16273  48835   25          3         11               4           8
# 16274  48836   48          1         12               0           8
# 16275  48837   33          3          9               4          10
# 16276  48838   39          3          9               0          10
# 16277  48839   64          8         11               6           0
# 16278  48840   38          3          9               2          10
# 16279  48841   44          3          9               0           1
# 16280  48842   35          4          9               2           4
#
#        Relationship  Race  Sex  Hours.Per.Week  Native.Country
# 0                 3     2    1              40              37
# 1                 0     4    1              50              37
# 2                 0     4    1              40              37
# 3                 0     2    1              40              37
# 4                 3     4    0              30              37
# 5                 1     4    1              30              37
# 6                 4     2    1              40              37
# 7                 0     4    1              32              37
# 8                 4     4    0              40              37
# 9                 0     4    1              10              37
# 10                0     4    1              40              37
# 11                0     4    1              40              37
# 12                1     4    0              39              37
# 13                0     4    1              35              37
# 14                0     4    1              48              37
# 15                0     4    1              50              37
# 16                3     4    1              25              37
# 17                5     4    0              30              37
# 18                4     4    0              20              37
# 19                0     1    1              45              37
# 20                0     4    1              47              37
# 21                3     2    0              35              37
# 22                1     4    0               6              37
# 23                1     4    1              43              27
# 24                0     4    1              40              37
# 25                0     4    1              90              37
# 26                3     4    1              20              37
# 27                4     2    1              54              37
# 28                0     4    1              35              37
# 29                1     4    1              60              37
# ...             ...   ...  ...             ...             ...
# 16251             0     4    1              20              37
# 16252             0     4    1              40              37
# 16253             1     4    0              40              37
# 16254             0     4    1              50              37
# 16255             0     4    1              50              37
# 16256             3     4    1              40              37
# 16257             1     4    0              40              37
# 16258             0     4    1              40              37
# 16259             2     4    0               8              37
# 16260             1     4    0              45              37
# 16261             0     4    1              55              37
# 16262             0     4    1              40              37
# 16263             3     4    1              40              37
# 16264             1     4    1              32              37
# 16265             5     4    0              40              37
# 16266             1     4    0              32              37
# 16267             4     2    0              40              37
# 16268             1     4    1              36              37
# 16269             0     4    1              40              37
# 16270             0     4    1              40              37
# 16271             0     4    1              48              37
# 16272             0     4    1              40              37
# 16273             3     4    0              40              37
# 16274             1     4    1              40              37
# 16275             3     4    1              40              37
# 16276             1     4    0              36              37
# 16277             2     2    1              40              37
# 16278             0     4    1              50              37
# 16279             3     1    1              40              37
# 16280             0     4    1              60              37
#
# [16281 rows x 11 columns]

# %%
train['Hours.Per.Week'] = train['Hours.Per.Week'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-8136f786a143> in <module>()
# ----> 1 train['Hours.Per.Week'] = train['Hours.Per.Week'].astype(int)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    3052         # else, only a single dtype is given
#    3053         new_data = self._data.astype(dtype=dtype, copy=copy,
# -> 3054                                      raise_on_error=raise_on_error, **kwargs)
#    3055         return self._constructor(new_data).__finalize__(self)
#    3056
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    3187
#    3188     def astype(self, dtype, **kwargs):
# -> 3189         return self.apply('astype', dtype=dtype, **kwargs)
#    3190
#    3191     def convert(self, **kwargs):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3054
#    3055             kwargs['mgr'] = self
# -> 3056             applied = getattr(b, f)(**kwargs)
#    3057             result_blocks = _extend_blocks(applied, result_blocks)
#    3058
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     459                **kwargs):
#     460         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 461                             values=values, **kwargs)
#     462
#     463     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     502
#     503                 # _astype_nansafe works fine with 1-d only
# --> 504                 values = _astype_nansafe(values.ravel(), dtype, copy=True)
#     505                 values = values.reshape(self.shape)
#     506
#
# /usr/local/lib/python2.7/dist-packages/pandas/types/cast.pyc in _astype_nansafe(arr, dtype, copy)
#     529
#     530         if np.isnan(arr).any():
# --> 531             raise ValueError('Cannot convert NA to integer')
#     532     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#     533         # work around NumPy brokenness, #1987
#
# ValueError: Cannot convert NA to integer

# %%
x = int(3.4
        )

# %%
x
# Out:
# 3

# %%
train['Hours.Per.Week'] = int(train['Hours.Per.Week'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-3a25363d0958> in <module>()
# ----> 1 train['Hours.Per.Week'] = int(train['Hours.Per.Week'])
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     return wrapper
#
# TypeError: cannot convert the series to <type 'int'>

# %%
test.apply(lambda x: sum(x.isnull()))
# Out:
# ID                0
# Age               0
# Workclass         0
# Education         0
# Marital.Status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Hours.Per.Week    0
# Native.Country    0
# dtype: int64

# %%
int(mode(train['Hours.Per.Week'])[0][0])
# Out:
# 40

# %%
hours_Null_Indices = train[train['Hours.Per.Week'].isnull()].index

# %%
hours_Null_Indices
# Out:
# Int64Index([25828], dtype='int64')

# %%
train['Hours.Per.WeeK'][25828]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-fc407a408dc4> in <module>()
# ----> 1 train['Hours.Per.WeeK'][25828]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Hours.Per.WeeK'

# %%
train['Sex'][5]
# Out:
# 1

# %%
train['Income.Group'][25828] = 0
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
income_Null_Indices = train[train['Income.Group'].isnull()].index

# %%
income_Null_Indices
# Out:
# Int64Index([25828], dtype='int64')

# %%
# Inititate the algorithm
model_01 = DecisionTreeClassifier(max_depth = 10, min_samples_leaf = 100, max_features= 'sqrt')

# Fit the algorithm
x = model_01.fit(train[independent_variable], train[dependent_variable])

# %%
model_01.fit
# Out:
# <bound method DecisionTreeClassifier.fit of DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=100,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')>

# %%
model_01
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=100,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
x
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=100,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
model_01_predictions = model_01.predict(test[independent_variable])

# %%
model_01_predictions
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '<=50K'], dtype=object)

# %%
submission = pd.read_csv('sample_submission.csv')
submission.ID = test.ID
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-135-36b1273794e9> in <module>()
# ----> 1 submission = pd.read_csv('sample_submission.csv')
#       2 submission.ID = test.ID
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# IOError: File sample_submission.csv does not exist

# %%
## gradient Boosting Classifier
## predict the random-Forest classifier
## pRedict the ada boost classifier 
from sklearn.tree import DecisionTreeClassifier

# %%
dependent_variable = 'Income.Group'
independent_variable = ['Age', 'Education', 'Workclass', 'Sex', 'Hours.Per.Week']

print independent_variable

# Inititate the algorithm
model_02 = DecisionTreeClassifier(max_depth = 10, min_samples_leaf = 100, max_features= 'sqrt')

# Fit the algorithm
model_02.fit(train[independent_variable], train[dependent_variable])

# Model predictions
model_02_predictions = model_02.predict(test[independent_variable])
# Out:
# ['Age', 'Education', 'Workclass', 'Sex', 'Hours.Per.Week']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
dependent_variable = 'Income.Group'
independent_variable = [x for x in train.columns if x not in ['ID', dependent_variable]]

# Inititate the algorithm
model_03 = RandomForestClassifier(max_depth = 10, min_samples_leaf = 10, max_features= 'auto')

# Fit the algorithm
model_03.fit(train[independent_variable], train[dependent_variable])

# Model predictions
model_03_predictions = model_03.predict(train[independent_variable])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_03_predictions
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '<=50K'], dtype=object)

# %%
score(model_03_predictions, train['Income_Group'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-49d99667366c> in <module>()
# ----> 1 score(model_03_predictions, train['Income_Group'])
#
# NameError: name 'score' is not defined

# %%
 from sklearn.metrics import accuracy_score

# %%
accuracy_score(x,y)
# Out:
# 0.84393511169615554

# %%
x = train['Income.Group']

# %%
y = model_03_predictions

# %%
y
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '<=50K'], dtype=object)

# %%
# Out:
# 0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
# 5        <=50K
# 6        <=50K
# 7         >50K
# 8         >50K
# 9         >50K
# 10        >50K
# 11        >50K
# 12       <=50K
# 13       <=50K
# 14        >50K
# 15       <=50K
# 16       <=50K
# 17       <=50K
# 18       <=50K
# 19        >50K
# 20        >50K
# 21       <=50K
# 22       <=50K
# 23       <=50K
# 24       <=50K
# 25        >50K
# 26       <=50K
# 27        >50K
# 28       <=50K
# 29       <=50K
#          ...
# 25799     >50K
# 25800     >50K
# 25801    <=50K
# 25802     >50K
# 25803     >50K
# 25804    <=50K
# 25805    <=50K
# 25806    <=50K
# 25807    <=50K
# 25808     >50K
# 25809     >50K
# 25810    <=50K
# 25811    <=50K
# 25812    <=50K
# 25813    <=50K
# 25814    <=50K
# 25815     >50K
# 25816    <=50K
# 25817     >50K
# 25818    <=50K
# 25819    <=50K
# 25820    <=50K
# 25821    <=50K
# 25822    <=50K
# 25823    <=50K
# 25824    <=50K
# 25825     >50K
# 25826    <=50K
# 25827    <=50K
# 25828        0
# Name: Income.Group, dtype: object

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
dependent_variable = 'Income.Group'
independent_variable = [x for x in train.columns if x not in ['ID', dependent_variable]]

# Inititate the algorithm
# model_07 = GradientBoostingClassifier(learning_rate=0.5, n_estimators=1700, max_depth=3)

model_07 = GradientBoostingClassifier(learning_rate=0.2, n_estimators=195, max_depth=3)

# Fit the algorithm
model_07.fit(train[independent_variable], train[dependent_variable])

# Model predictions
model_07_predictions = model_07.predict(train[independent_variable])

# %%
model_07_predictions
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', 0], dtype=object)

# %%
len(model_07_predictions)
# Out:
# 25829

# %%
len(x)
# Out:
# 12

# %%
x = train['Income.Group']

# %%
len(x)
# Out:
# 25829

# %%
accuracy_score(x, model_07_predictions)
# Out:
# 0.85628557048279064
